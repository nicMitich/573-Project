# %%
#!pip install pdfminer.six   --> extracts text from PDF files
#!pip install spacy
#!python -m spacy download en_core_web_sm   --> NLP model for entity recognition/name extraction

# %%
from pdfminer.high_level import extract_text    # For extracting text from PDF files
import os                             # For handling file paths

def extract_text_from_pdf(pdf_path):
    return extract_text(pdf_path)       # Extract text from the pdf file into sample text

sample_text = extract_text_from_pdf('My Resume - SarvaGupta.pdf')       # Extract text from the specified PDF file
print(sample_text[:1000])       # Print the first 1000 characters to verify text extraction
# Out:
# Sarva Gupta
#
# Computer Science student with a strong foundation in software development, algorithms, artiﬁcial intelligence, and data-driven systems, built through
# undergraduate and graduate coursework. Experienced in delivering technical, data-oriented, and full-stack projects, collaborating across teams, and
# communicating complex ideas eﬀectively.
#
# sarva.gupta.3@gmail.com
#
# 602-223-1850
#
# Phoenix, AZ, United States
#
# linkedin.com/in/sarva-gupta-42826b256
#
# EDUCATION
#
# SKILLS
#
# Master of Science in Computer Science
# Arizona State University
# 01/2025 - 05/2026,
#
# Python
#
# Java
#
# C#
#
# JavaScript
#
# SQL
#
# Tempe, AZ
#
# ASP .NET
#
# Rest APIs
#
# HTML
#
# CSS
#
# Git
#
# Bachelor of Science in Computer Science
# ASU (Barrett, the Honors College)
# 08/2021 - 12/2024,
#
# Tempe, AZ, 3.50
#
# Visual Studio
#
# Firebase
#
# Linux
#
# Figma
#
# React
#
# Taiga
#
# Agile
#
# UI/UX Design
#
# High School (with Honors)
# BASIS Phoenix
# 08/2017 - 05/2021,
#
# Phoenix, AZ, 3.83
#
# PROJECTS
#
# WORK EXPERIENCE
#
# Undergraduate Teaching

# %%
import re       # For regular expressions to clean the text

def clean_text(text):
    text = re.sub(r'\n+', '\n', text)  # Replace multiple newlines with a single newline   
    # \n = newline, + = 1/more so \n+ = 1/more newlines
    text = re.sub(r' +', ' ', text)  # Replace multiple spaces with a single space
        # ' ' = space, + = 1/more so ' '+ = 1/more spaces
    return text.strip()

cleaned_text = clean_text(sample_text)      # Clean the extracted text to make it easier to parse and use
print(cleaned_text)     # Print the cleaned text to verify the cleaning process
# Out:
# Sarva Gupta
# Computer Science student with a strong foundation in software development, algorithms, artiﬁcial intelligence, and data-driven systems, built through
# undergraduate and graduate coursework. Experienced in delivering technical, data-oriented, and full-stack projects, collaborating across teams, and
# communicating complex ideas eﬀectively.
# sarva.gupta.3@gmail.com
# 602-223-1850
# Phoenix, AZ, United States
# linkedin.com/in/sarva-gupta-42826b256
# EDUCATION
# SKILLS
# Master of Science in Computer Science
# Arizona State University
# 01/2025 - 05/2026,
# Python
# Java
# C#
# JavaScript
# SQL
# Tempe, AZ
# ASP .NET
# Rest APIs
# HTML
# CSS
# Git
# Bachelor of Science in Computer Science
# ASU (Barrett, the Honors College)
# 08/2021 - 12/2024,
# Tempe, AZ, 3.50
# Visual Studio
# Firebase
# Linux
# Figma
# React
# Taiga
# Agile
# UI/UX Design
# High School (with Honors)
# BASIS Phoenix
# 08/2017 - 05/2021,
# Phoenix, AZ, 3.83
# PROJECTS
# WORK EXPERIENCE
# Undergraduate Teaching Assistant - Intro to
# Informatics
# Ira A. Fulton Schools of Engineering, ASU
# 08/2024 - 12/2024,
# Supported undergraduate coursework by reinforcing core computing concepts,
# assisting students with problem-solving, and contributing to a collaborative
# learning environment.
# Tempe, AZ
# Achievements/Tasks
# Supported 200+ students in Python-based coursework covering
# basics of Informatics, including data structures, algorithms, and
# problem-solving
# Led oﬃce hours and exam review sessions, clarifying algorithmic
# thinking and debugging strategies
# SWE Capstone – Full Stack Developer
# Ira A. Fulton Schools of Engineering, ASU
# 01/2024 - 12/2024,
# Tempe, AZ
# A year-long, team-based software engineering project with real-world stakeholders
# Achievements/Tasks
# Developed a web app using the PERN stack (PostgreSQL, Express,
# React, Node.js) to support mental-health peer communities
# Collaborated in an Agile team environment, coordinating with
# designers, peer leaders, and a startup founder
# Student Success Oﬃce Assistant
# Ira A. Fulton Schools of Engineering, ASU
# 10/2024 - 12/2025,
# Provided front-line academic and event support, assisting students and staﬀ in
# navigating programs, resources, and activities.
# Tempe, AZ
# Achievements/Tasks
# Supported planning, setup, and execution of academic and student-
# focused events hosted by the Fulton Schools of Engineering
# Assisted students by providing directions and guidance to campus
# resources, oﬃces, and locations
# Honors Thesis: UX Research & Data-Driven Web Redesign
#  (07/2024 - 12/2024)
# Conducted UX research to evaluate accessibility and discoverability of
# mental-health resources on the ASU website
# Designed and proposed a data-driven redesign to improve navigation
# eﬃciency and applied user-centered design principles and usability testing,
# Interactive Scrollytelling Data Visualization Website
#  (01/2025 - 05/2025)
# Designed and developed an interactive scrollytelling website using D3.js,
# JavaScript, HTML, and CSS to explore the evolution of the internet
# Collaborated in a team to architect the site from scratch, integrating multiple
# visual components into a cohesive user experience
# Machine Learning & Data Mining Analysis (08/2025 - 12/2025)
# Evaluated and compared model performance using accuracy and other
# metrics to identify optimal approaches
# Collaborated with a team to preprocess data from a real-world dataset,
# engineer features, and interpret results
# Integrated Mobile, Web App, and AI Development Projects
#  (01/2024 - Present)
# Implemented heuristic search, planning, and reinforcement learning
# algorithms (GBFS, UCS, A*, Q-learning, SARSA) to optimize agent behavior in
# simulated environments.
# Developed a cross-platform mobile application using Xamarin to consume
# asynchronous RESTful services with secure encryption and decryption via a
# graphical user interface.
# Built and deployed RESTful services using ASP.NET and IIS, implementing URI
# template–based endpoints and integrating with an HTML5 web application.
# Applied LINQ queries in a C# console application to process and analyze
# course data from CSV ﬁles using the .NET framework.
# ACHIEVEMENTS
# Grand Challenges Scholar (01/2022 - 12/2024)
# Explored world themes : Joy of Living, Sustainability, Health, and Security through
# interdisciplinary projects, courses, and research
# LANGUAGES
# English
# Native or Bilingual Proﬁciency
# Hindi
# Native or Bilingual Proﬁciency
# French
# Professional Working Proﬁciency

# %%
def extract_email(text):        # Extract email addresses using a regular expression
    match = re.search(r'\S+@\S+', text)     # \S = non-whitespace, + = 1/more so \S+ = 1/more non-whitespace, @ = @ symbol
    return match.group(0) if match else None        # Return the matched email address if found, otherwise return None

def extract_phone_number(text):         # Extract phone numbers using a regular expression
    match = re.search(r'\+?\d[\d -]{8,}\d', text)       # \+? = optional + at the start, \d = digit, [\d -]{8,} = 8 or more digits/spaces/hyphens, \d = digit at the end
    return match.group(0) if match else None    # Return the matched phone number if found, otherwise return None

email = extract_email(cleaned_text)     # Extract the email address from the cleaned text
phone_number = extract_phone_number(cleaned_text)       # Extract the phone number from the cleaned text
print(f"Extracted Email: {email}")
print(f"Extracted Phone Number: {phone_number}")        # Print the extracted email and phone number to verify the extraction process
# Out:
# Extracted Email: sarva.gupta.3@gmail.com
# Extracted Phone Number: 602-223-1850

# %%
import spacy        # For natural language processing and entity recognition to extract the name from the resume
# spaCy NER is the Named Entity Recognition feature within the spaCy open-source 
# library for Natural Language Processing (NLP) in Python

nlp = spacy.load('en_core_web_sm')

def extract_name(text):     # Use spaCy's named entity recognition to extract the person's name from the text
    doc = nlp(text)
    for ent in doc.ents:
        if ent.label_ == 'PERSON':  
            return ent.text
    return None

name = extract_name(cleaned_text)
print(f"Extracted Name: {name}")        # Print the extracted name to verify the extraction process
# Out:
# Extracted Name: Sarva Gupta

# %%
# SKILL_SET = {'python', 'java', 'c++', 'machine learning', 'data analysis', 'sql', 'javascript'}

SKILL_SET = {
    # Programming Languages - excluding r, 
    'python', 'java', 'c', 'c++', 'c#', 'go', 'rust', 'scala',
    'javascript', 'typescript', 'matlab', 'bash', 'shell',

    # Web & Frontend
    'html', 'css', 'react', 'angular', 'vue', 'next.js', 'node.js',
    'express', 'rest', 'graphql',

    # Backend & Frameworks
    'django', 'flask', 'fastapi', 'spring', 'spring boot',
    '.net', 'asp.net',

    # Databases
    'sql', 'mysql', 'postgresql', 'sqlite', 'mongodb', 'redis',
    'nosql',

    # Data / ML / AI
    'machine learning', 'deep learning', 'artificial intelligence',
    'data analysis', 'data science', 'nlp', 'computer vision',
    'pandas', 'numpy', 'scikit-learn', 'tensorflow', 'pytorch',

    # Cloud & DevOps
    'aws', 'azure', 'gcp', 'docker', 'kubernetes',
    'ci/cd', 'jenkins', 'terraform',

    # Tools & Platforms
    'git', 'github', 'gitlab', 'bitbucket',
    'linux', 'unix', 'windows',

    # Software Engineering Practices
    'agile', 'scrum', 'kanban', 'oop', 'object oriented programming',
    'microservices', 'system design',

    # Testing
    'unit testing', 'integration testing', 'pytest', 'junit',

    # Visualization & UX
    'd3.js', 'tableau', 'power bi', 'figma', 'ux', 'ui',

    # Security
    'cybersecurity', 'authentication', 'authorization', 'oauth',
    'encryption'
}


def extract_skills(text, skills=SKILL_SET):
    found = [skill for skill in skills if skill.lower() in text.lower()]       # Check if each skill in the SKILL_SET is present in the text (case-insensitive) and collect the found skills in a list
    return list(set(found))  # Remove duplicates by converting to a set and back to a list

skillsList = extract_skills(cleaned_text)
print(f"Extracted Skills: ")
print(skillsList)
print(f"Total skills found:", len(skillsList))      # Print the total number of unique skills found in the resume
# Out:
# Extracted Skills:
# ['d3.js', 'machine learning', 'python', 'c#', 'c', 'html', 'asp.net', 'java', 'git', '.net', 'node.js', 'ux', 'encryption', 'agile', 'figma', 'javascript', 'postgresql', 'react', 'go', 'ui', 'css', 'rest', 'express', 'sql', 'linux']
# Total skills found: 25

# %%
EDUCATION_KEYWORDS = ['Associate', 'Associates', 'Bachelor', 'Master', 'Bachelors', 'Masters', 'B.Sc', 'M.Sc', 'PhD', 'B.E', 'M.E.']

def extract_education(text):
    lines = text.split('\n')     # Split the text into lines to check for education-related keywords in each line
    education_info = []
    for line in lines:
        if any(keyword in line for keyword in EDUCATION_KEYWORDS):     # Check if any of the education-related keywords are present in the line
            education_info.append(line.strip())     # If a line contains any of the education keywords, add it to the education_info list after stripping leading/trailing whitespace
    return education_info

education_details = extract_education(cleaned_text)  # Extract education details from the cleaned text and store them in a list
print("Extracted Education Details:")
for edu in education_details:
    print("-", edu)    # Print each extracted education detail to verify the extraction process
# Out:
# Extracted Education Details:
# - Master of Science in Computer Science
# - Bachelor of Science in Computer Science

# %%
def extract_experience(text):
    experience_keywords = ['experience', 'work', 'employment', 'internship']  # Keywords to identify lines related to work experience in the resume
    experience_lines = []
    lines = text.split('\n')
    for line in lines:
        if any(keyword in line.lower() for keyword in experience_keywords):  # Check if any of the experience-related keywords are present in the line (case-insensitive)
            experience_lines.append(line.strip())
    return experience_lines

experience_details = extract_experience(cleaned_text)  # Extract experience details from the cleaned text and store them in a list
print("Extracted Experience Details:")
for exp in experience_details:
    print("-", exp)   # Print each extracted experience detail to verify the extraction process
# Out:
# Extracted Experience Details:
# - undergraduate and graduate coursework. Experienced in delivering technical, data-oriented, and full-stack projects, collaborating across teams, and
# - WORK EXPERIENCE
# - Supported undergraduate coursework by reinforcing core computing concepts,
# - Supported 200+ students in Python-based coursework covering
# - visual components into a cohesive user experience
# - course data from CSV ﬁles using the .NET framework.
# - Professional Working Proﬁciency

# %%
parsed_resume = {     # Create a dictionary to store all the extracted information from the resume in a structured format
    'name': extract_name(cleaned_text),
    'email': extract_email(cleaned_text),
    'phone_number': extract_phone_number(cleaned_text),
    'skills': extract_skills(cleaned_text),
    'education': extract_education(cleaned_text),
    'experience': extract_experience(cleaned_text)
}

print("Parsed Resume:")    # Print the structured dictionary containing all the extracted information from the resume
for key, value in parsed_resume.items():
    print(f"{key.capitalize()}: {value}")
# Out:
# Parsed Resume:
# Name: Sarva Gupta
# Email: sarva.gupta.3@gmail.com
# Phone_number: 602-223-1850
# Skills: ['d3.js', 'machine learning', 'python', 'c#', 'c', 'html', 'asp.net', 'java', 'git', '.net', 'node.js', 'ux', 'encryption', 'agile', 'figma', 'javascript', 'postgresql', 'react', 'go', 'ui', 'css', 'rest', 'express', 'sql', 'linux']
# Education: ['Master of Science in Computer Science', 'Bachelor of Science in Computer Science']
# Experience: ['undergraduate and graduate coursework. Experienced in delivering technical, data-oriented, and full-stack projects, collaborating across teams, and', 'WORK EXPERIENCE', 'Supported undergraduate coursework by reinforcing core computing concepts,', 'Supported 200+ students in Python-based coursework covering', 'visual components into a cohesive user experience', 'course data from CSV ﬁles using the .NET framework.', 'Professional Working Proﬁciency']

# %%
import pandas as pd   # For handling data in a structured format and exporting to CSV
import os

def process_folder(folder_path):  # Process all PDF files in the specified folder, extract relevant information, and compile it into a DataFrame
    resumes_data = []
    for filename in os.listdir(folder_path):  # Iterate through all files in the specified folder
        if filename.endswith('.pdf'):
            pdf_path = os.path.join(folder_path, filename)
            text = extract_text_from_pdf(pdf_path)
            cleaned_text = clean_text(text)
            parsed_resume = {
                'name': extract_name(cleaned_text),
                'email': extract_email(cleaned_text),
                'phone_number': extract_phone_number(cleaned_text),
                'skills': extract_skills(cleaned_text),
                'education': extract_education(cleaned_text),
                'experience': extract_experience(cleaned_text)
            }
            resumes_data.append(parsed_resume)  # Append the structured dictionary for each resume to the resumes_data list
    return pd.DataFrame(resumes_data)

df = process_folder('resumes')   # Process all resumes in the 'resumes' folder and compile the extracted information into a DataFrame
df.to_csv('parsed_resumes.csv', index=False)
